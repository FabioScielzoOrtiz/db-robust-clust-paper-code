# %% [markdown]
# **TO DO: con esta simulacion hay que hacer también el anaálisis de estabilidad (sección 3.2)**
#
# código en `C:\Users\fscielzo\Documents\PhD\TFM\Clustering\FastKmedoids_Stability.ipynb`
