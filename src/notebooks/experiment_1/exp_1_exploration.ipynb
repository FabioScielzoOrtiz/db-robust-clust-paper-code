# %%
import os, sys
import pickle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_style('whitegrid')

#################################################################################################################

script_path = os.getcwd()
project_path = os.path.join(script_path, '..', '..', '..')
results_dir = os.path.join(project_path, 'results', 'experiment_1')
results_path = os.path.join(results_dir, 'results_exp_1.pkl')
save_path = os.path.join(results_dir, 'plot_results_exp_1.png')

#################################################################################################################

sys.path.append(project_path)
from config.config_experiment_1 import CONFIG_EXPERIMENT 
from src.utils.experiments_exploration_utils import plot_experiment_1_results

#################################################################################################################

data_sizes = CONFIG_EXPERIMENT['data_sizes']

with open(results_path, 'rb') as f:
    time_results = pickle.load(f)

# %%
plot_experiment_1_results(time_results, data_sizes, save_path)
