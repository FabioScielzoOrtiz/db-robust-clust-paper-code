# %%
import os, sys
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
script_path = os.getcwd()
project_path = os.path.abspath(os.path.join(script_path, '..', '..', '..'))

results_exp_2a_dir = os.path.join(project_path, 'results', 'experiment_2a')
results_exp_2a_path = os.path.join(results_exp_2a_dir, 'master_table_exp_2a.parquet')

results_exp_2b_dir = os.path.join(project_path, 'results', 'experiment_2b')
results_exp_2b_path = os.path.join(results_exp_2b_dir, 'master_table_exp_2b.parquet')

# %%
df_results_exp_2a = pl.read_parquet(results_exp_2a_path)
df_results_exp_2b = pl.read_parquet(results_exp_2b_path)

# %%
df_results_exp_2a
# Out:
# shape: (25, 37)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ sample_siz ┆ mean_acc ┆ std_acc  ┆ mean_ari ┆ … ┆ imbalance_ ┆ imbalance ┆ is_balanc ┆ convex_ge │
# │ e_pct      ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ratio      ┆ _ratio_st ┆ ed        ┆ ometry    │
# │ ---        ┆ f64      ┆ f64      ┆ f64      ┆   ┆ ---        ┆ d         ┆ ---       ┆ ---       │
# │ f64        ┆          ┆          ┆          ┆   ┆ f64        ┆ ---       ┆ bool      ┆ bool      │
# │            ┆          ┆          ┆          ┆   ┆            ┆ f64       ┆           ┆           │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 0.5        ┆ 0.83808  ┆ 0.1021   ┆ 0.630713 ┆ … ┆ 1.0003     ┆ 0.0       ┆ true      ┆ true      │
# │ 10.0       ┆ 0.860289 ┆ 0.104518 ┆ 0.676921 ┆ … ┆ 1.0003     ┆ 0.0       ┆ true      ┆ true      │
# ...

# %%
df_results_exp_2b
# Out:
# shape: (15, 37)
# ┌────────────┬──────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ sample_siz ┆ mean_acc ┆ std_acc  ┆ mean_ari ┆ … ┆ imbalance_ ┆ imbalance ┆ is_balanc ┆ convex_ge │
# │ e_pct      ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ratio      ┆ _ratio_st ┆ ed        ┆ ometry    │
# │ ---        ┆ f64      ┆ f64      ┆ f64      ┆   ┆ ---        ┆ d         ┆ ---       ┆ ---       │
# │ f64        ┆          ┆          ┆          ┆   ┆ f64        ┆ ---       ┆ bool      ┆ bool      │
# │            ┆          ┆          ┆          ┆   ┆            ┆ f64       ┆           ┆           │
# ╞════════════╪══════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 0.5        ┆ 0.865534 ┆ 0.069312 ┆ 0.671094 ┆ … ┆ 1.0003     ┆ 0.0       ┆ true      ┆ true      │
# │ 10.0       ┆ 0.886914 ┆ 0.022581 ┆ 0.703472 ┆ … ┆ 1.0003     ┆ 0.0       ┆ true      ┆ true      │
# ...
