# %%
import os, sys

# %%
DATA_ID = 'kc_houses' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_2', DATA_ID)
filename = f'results_exp_2_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_2_results, plot_experiment_2_results
from config.config_experiment_2 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_2_results(
    results_path=results_path,
    num_realizations=N_REALIZATIONS,
    prop_errors_threshold=PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 100

# %%
df
# Out:
# shape: (600, 8)
# ┌─────────────┬─────────────┬───────────┬────────────┬──────────┬────────┬────────────┬────────────┐
# │ random_stat ┆ frac_sample ┆ time      ┆ adj_accura ┆ ARI      ┆ status ┆ status_err ┆ sample_siz │
# │ e           ┆ _size       ┆ ---       ┆ cy         ┆ ---      ┆ ---    ┆ or         ┆ e_pct      │
# │ ---         ┆ ---         ┆ f64       ┆ ---        ┆ f64      ┆ str    ┆ ---        ┆ ---        │
# │ i64         ┆ f64         ┆           ┆ f64        ┆          ┆        ┆ bool       ┆ f64        │
# ╞═════════════╪═════════════╪═══════════╪════════════╪══════════╪════════╪════════════╪════════════╡
# │ 6863        ┆ 0.005       ┆ 6.069753  ┆ 0.398264   ┆ 0.012721 ┆ OK     ┆ false      ┆ 0.5        │
# │ 6863        ┆ 0.01        ┆ 6.099433  ┆ 0.417638   ┆ 0.029986 ┆ OK     ┆ false      ┆ 1.0        │
# │ 6863        ┆ 0.05        ┆ 6.921016  ┆ 0.41154    ┆ 0.028933 ┆ OK     ┆ false      ┆ 5.0        │
# │ 6863        ┆ 0.1         ┆ 24.343982 ┆ 0.435089   ┆ 0.044964 ┆ OK     ┆ false      ┆ 10.0       │
# │ 6863        ┆ 0.2         ┆ 37.626192 ┆ 0.436373   ┆ 0.0423   ┆ OK     ┆ false      ┆ 20.0       │
# │ …           ┆ …           ┆ …         ┆ …          ┆ …        ┆ …      ┆ …          ┆ …          │
# │ 30032       ┆ 0.01        ┆ 6.81269   ┆ 0.517616   ┆ 0.081565 ┆ OK     ┆ false      ┆ 1.0        │
# │ 30032       ┆ 0.05        ┆ 6.671447  ┆ 0.46205    ┆ 0.053701 ┆ OK     ┆ false      ┆ 5.0        │
# │ 30032       ┆ 0.1         ┆ 7.307368  ┆ 0.426236   ┆ 0.036096 ┆ OK     ┆ false      ┆ 10.0       │
# │ 30032       ┆ 0.2         ┆ 10.906631 ┆ 0.395414   ┆ 0.02318  ┆ OK     ┆ false      ┆ 20.0       │
# │ 30032       ┆ 0.3         ┆ 15.420724 ┆ 0.427289   ┆ 0.034629 ┆ OK     ┆ false      ┆ 30.0       │
# └─────────────┴─────────────┴───────────┴────────────┴──────────┴────────┴────────────┴────────────┘

# %%
df_avg
# Out:
# shape: (6, 8)
# ┌───────────────┬──────────┬──────────┬──────────┬──────────┬───────────┬───────────┬──────────────┐
# │ sample_size_p ┆ mean_acc ┆ std_acc  ┆ mean_ari ┆ std_ari  ┆ mean_time ┆ std_time  ┆ prop_status_ │
# │ ct            ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---       ┆ ---       ┆ error        │
# │ ---           ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64       ┆ f64       ┆ ---          │
# │ f64           ┆          ┆          ┆          ┆          ┆           ┆           ┆ f64          │
# ╞═══════════════╪══════════╪══════════╪══════════╪══════════╪═══════════╪═══════════╪══════════════╡
# │ 0.5           ┆ 0.433807 ┆ 0.04448  ┆ 0.038011 ┆ 0.024665 ┆ 12.438493 ┆ 8.833523  ┆ 0.0          │
# │ 1.0           ┆ 0.442297 ┆ 0.04138  ┆ 0.041781 ┆ 0.024057 ┆ 12.158274 ┆ 8.640257  ┆ 0.0          │
# │ 5.0           ┆ 0.451639 ┆ 0.028509 ┆ 0.048234 ┆ 0.015617 ┆ 11.663637 ┆ 8.262504  ┆ 0.0          │
# │ 10.0          ┆ 0.45199  ┆ 0.029728 ┆ 0.050013 ┆ 0.016234 ┆ 12.404026 ┆ 8.412836  ┆ 0.0          │
# │ 20.0          ┆ 0.450162 ┆ 0.026966 ┆ 0.048909 ┆ 0.014228 ┆ 17.273978 ┆ 10.486169 ┆ 0.0          │
# │ 30.0          ┆ 0.442143 ┆ 0.022446 ┆ 0.044059 ┆ 0.011852 ┆ 25.947253 ┆ 14.986424 ┆ 0.0          │
# └───────────────┴──────────┴──────────┴──────────┴──────────┴───────────┴───────────┴──────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.05
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.05
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.39622946779645496, 0.49622946779645494)
# ylim_ari: (-0.003853856483427287, 0.09614614351657272)
# ylim_time: (10.421259704828262, 14.421259704828262)

# %%
error_style = None
plot_filename = f'plot_results_exp_2_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'fill'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'bar'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'boxplot'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df,
    df_avg=df_avg, 
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)
