# %%
import os, sys

# %%
DATA_ID = 'simulation_3' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_2', DATA_ID)
filename = f'results_exp_2_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_2_results, plot_experiment_2_results
from config.config_experiment_2 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_2_results(
    results_path=results_path,
    num_realizations=N_REALIZATIONS,
    prop_errors_threshold=PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 69

# %%
df
# Out:
# shape: (414, 8)
# ┌─────────────┬────────────┬────────────┬────────────┬──────────┬────────┬────────────┬────────────┐
# │ random_stat ┆ frac_sampl ┆ time       ┆ adj_accura ┆ ARI      ┆ status ┆ status_err ┆ sample_siz │
# │ e           ┆ e_size     ┆ ---        ┆ cy         ┆ ---      ┆ ---    ┆ or         ┆ e_pct      │
# │ ---         ┆ ---        ┆ f64        ┆ ---        ┆ f64      ┆ str    ┆ ---        ┆ ---        │
# │ i64         ┆ f64        ┆            ┆ f64        ┆          ┆        ┆ bool       ┆ f64        │
# ╞═════════════╪════════════╪════════════╪════════════╪══════════╪════════╪════════════╪════════════╡
# │ 6863        ┆ 0.0005     ┆ 92.860666  ┆ 0.877317   ┆ 0.680922 ┆ OK     ┆ false      ┆ 0.05       │
# │ 6863        ┆ 0.005      ┆ 92.579129  ┆ 0.828537   ┆ 0.591368 ┆ OK     ┆ false      ┆ 0.5        │
# │ 6863        ┆ 0.01       ┆ 92.890565  ┆ 0.832017   ┆ 0.59773  ┆ OK     ┆ false      ┆ 1.0        │
# │ 6863        ┆ 0.05       ┆ 133.142077 ┆ 0.770017   ┆ 0.509455 ┆ OK     ┆ false      ┆ 5.0        │
# │ 6863        ┆ 0.1        ┆ 301.585562 ┆ 0.770013   ┆ 0.509463 ┆ OK     ┆ false      ┆ 10.0       │
# │ …           ┆ …          ┆ …          ┆ …          ┆ …        ┆ …      ┆ …          ┆ …          │
# │ 54984       ┆ 0.005      ┆ 174.875226 ┆ 0.836717   ┆ 0.606046 ┆ OK     ┆ false      ┆ 0.5        │
# │ 54984       ┆ 0.01       ┆ 183.110516 ┆ 0.835347   ┆ 0.603538 ┆ OK     ┆ false      ┆ 1.0        │
# │ 54984       ┆ 0.05       ┆ 267.84498  ┆ 0.773567   ┆ 0.514763 ┆ OK     ┆ false      ┆ 5.0        │
# │ 54984       ┆ 0.1        ┆ 488.055423 ┆ 0.768493   ┆ 0.508673 ┆ OK     ┆ false      ┆ 10.0       │
# │ 54984       ┆ 0.2        ┆ 2283.26488 ┆ 0.836157   ┆ 0.604568 ┆ OK     ┆ false      ┆ 20.0       │
# │             ┆            ┆ 6          ┆            ┆          ┆        ┆            ┆            │
# └─────────────┴────────────┴────────────┴────────────┴──────────┴────────┴────────────┴────────────┘

# %%
df_avg
# Out:
# shape: (6, 8)
# ┌──────────────┬──────────┬──────────┬──────────┬──────────┬─────────────┬───────────┬─────────────┐
# │ sample_size_ ┆ mean_acc ┆ std_acc  ┆ mean_ari ┆ std_ari  ┆ mean_time   ┆ std_time  ┆ prop_status │
# │ pct          ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       ┆ _error      │
# │ ---          ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       ┆ ---         │
# │ f64          ┆          ┆          ┆          ┆          ┆             ┆           ┆ f64         │
# ╞══════════════╪══════════╪══════════╪══════════╪══════════╪═════════════╪═══════════╪═════════════╡
# │ 0.05         ┆ 0.84155  ┆ 0.036416 ┆ 0.617907 ┆ 0.062125 ┆ 104.253231  ┆ 33.006373 ┆ 0.0         │
# │ 0.5          ┆ 0.81973  ┆ 0.032566 ┆ 0.582234 ┆ 0.044301 ┆ 104.551859  ┆ 33.702781 ┆ 0.0         │
# │ 1.0          ┆ 0.821644 ┆ 0.029766 ┆ 0.58476  ┆ 0.040406 ┆ 105.651368  ┆ 34.690763 ┆ 0.0         │
# │ 5.0          ┆ 0.796034 ┆ 0.036099 ┆ 0.548425 ┆ 0.049401 ┆ 151.108308  ┆ 46.334254 ┆ 0.0         │
# │ 10.0         ┆ 0.793704 ┆ 0.034823 ┆ 0.544806 ┆ 0.0477   ┆ 311.055373  ┆ 92.356626 ┆ 0.0         │
# │ 20.0         ┆ 0.782681 ┆ 0.029227 ┆ 0.528878 ┆ 0.040668 ┆ 1134.878031 ┆ 544.65538 ┆ 0.0         │
# └──────────────┴──────────┴──────────┴──────────┴──────────┴─────────────┴───────────┴─────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.05
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.05
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.7578820772946859, 0.857882077294686)
# ylim_ari: (0.5153295423364941, 0.6153295423364942)
# ylim_time: (126.37983778594196, 130.37983778594196)

# %%
error_style = None
plot_filename = f'plot_results_exp_2_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'fill'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'bar'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'boxplot'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df,
    df_avg=df_avg, 
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)
