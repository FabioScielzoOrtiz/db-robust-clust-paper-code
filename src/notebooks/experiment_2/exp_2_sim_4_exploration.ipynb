# %%
import os, sys

# %%
DATA_ID = 'simulation_4' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_2', DATA_ID)
filename = f'results_exp_2_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_2_results, plot_experiment_2_results
from config.config_experiment_2 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_2_results(
    results_path=results_path,
    num_realizations=N_REALIZATIONS,
    prop_errors_threshold=PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 50

# %%
df
# Out:
# shape: (250, 8)
# ┌─────────────┬────────────┬────────────┬────────────┬──────────┬────────┬────────────┬────────────┐
# │ random_stat ┆ frac_sampl ┆ time       ┆ adj_accura ┆ ARI      ┆ status ┆ status_err ┆ sample_siz │
# │ e           ┆ e_size     ┆ ---        ┆ cy         ┆ ---      ┆ ---    ┆ or         ┆ e_pct      │
# │ ---         ┆ ---        ┆ f64        ┆ ---        ┆ f64      ┆ str    ┆ ---        ┆ ---        │
# │ i64         ┆ f64        ┆            ┆ f64        ┆          ┆        ┆ bool       ┆ f64        │
# ╞═════════════╪════════════╪════════════╪════════════╪══════════╪════════╪════════════╪════════════╡
# │ 3431        ┆ 0.0005     ┆ 386.318352 ┆ 0.845408   ┆ 0.620774 ┆ OK     ┆ false      ┆ 0.05       │
# │ 3431        ┆ 0.005      ┆ 391.917259 ┆ 0.775447   ┆ 0.516247 ┆ OK     ┆ false      ┆ 0.5        │
# │ 3431        ┆ 0.01       ┆ 409.718472 ┆ 0.829697   ┆ 0.593416 ┆ OK     ┆ false      ┆ 1.0        │
# │ 3431        ┆ 0.05       ┆ 1276.41276 ┆ 0.762079   ┆ 0.500434 ┆ OK     ┆ false      ┆ 5.0        │
# │             ┆            ┆ 2          ┆            ┆          ┆        ┆            ┆            │
# │ 3431        ┆ 0.08       ┆ 2503.81496 ┆ 0.83307    ┆ 0.598848 ┆ OK     ┆ false      ┆ 8.0        │
# │             ┆            ┆ 8          ┆            ┆          ┆        ┆            ┆            │
# │ …           ┆ …          ┆ …          ┆ …          ┆ …        ┆ …      ┆ …          ┆ …          │
# │ 13556       ┆ 0.0005     ┆ 317.923911 ┆ 0.852874   ┆ 0.633336 ┆ OK     ┆ false      ┆ 0.05       │
# │ 13556       ┆ 0.005      ┆ 321.714369 ┆ 0.764652   ┆ 0.503448 ┆ OK     ┆ false      ┆ 0.5        │
# │ 13556       ┆ 0.01       ┆ 333.315237 ┆ 0.771342   ┆ 0.510453 ┆ OK     ┆ false      ┆ 1.0        │
# │ 13556       ┆ 0.05       ┆ 935.405994 ┆ 0.77218    ┆ 0.51159  ┆ OK     ┆ false      ┆ 5.0        │
# │ 13556       ┆ 0.08       ┆ 2174.81726 ┆ 0.772173   ┆ 0.511601 ┆ OK     ┆ false      ┆ 8.0        │
# │             ┆            ┆ 8          ┆            ┆          ┆        ┆            ┆            │
# └─────────────┴────────────┴────────────┴────────────┴──────────┴────────┴────────────┴────────────┘

# %%
df_avg
# Out:
# shape: (5, 8)
# ┌─────────────┬──────────┬──────────┬──────────┬──────────┬─────────────┬────────────┬─────────────┐
# │ sample_size ┆ mean_acc ┆ std_acc  ┆ mean_ari ┆ std_ari  ┆ mean_time   ┆ std_time   ┆ prop_status │
# │ _pct        ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---        ┆ _error      │
# │ ---         ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64        ┆ ---         │
# │ f64         ┆          ┆          ┆          ┆          ┆             ┆            ┆ f64         │
# ╞═════════════╪══════════╪══════════╪══════════╪══════════╪═════════════╪════════════╪═════════════╡
# │ 0.05        ┆ 0.827645 ┆ 0.044836 ┆ 0.597931 ┆ 0.062874 ┆ 321.682846  ┆ 46.235582  ┆ 0.0         │
# │ 0.5         ┆ 0.804387 ┆ 0.038238 ┆ 0.560599 ┆ 0.049651 ┆ 334.021987  ┆ 71.436207  ┆ 0.0         │
# │ 1.0         ┆ 0.802081 ┆ 0.035482 ┆ 0.556453 ┆ 0.048632 ┆ 358.473542  ┆ 87.970241  ┆ 0.0         │
# │ 5.0         ┆ 0.777238 ┆ 0.029502 ┆ 0.522148 ┆ 0.037842 ┆ 917.954886  ┆ 285.380228 ┆ 0.0         │
# │ 8.0         ┆ 0.773773 ┆ 0.030179 ┆ 0.518243 ┆ 0.03541  ┆ 2383.275651 ┆ 541.999502 ┆ 0.0         │
# └─────────────┴──────────┴──────────┴──────────┴──────────┴─────────────┴────────────┴─────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.05
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.05
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.7520807, 0.8520807000000001)
# ylim_ari: (0.5064530936708221, 0.6064530936708222)
# ylim_time: (356.4735415172577, 360.4735415172577)

# %%
error_style = None
plot_filename = f'plot_results_exp_2_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'fill'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'bar'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'boxplot'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df,
    df_avg=df_avg, 
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)
