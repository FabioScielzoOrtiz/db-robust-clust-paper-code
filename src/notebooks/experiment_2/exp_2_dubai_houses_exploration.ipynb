# %%
import os, sys

# %%
DATA_ID = 'dubai_houses' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_2', DATA_ID)
filename = f'results_exp_2_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_2_results, plot_experiment_2_results
from config.config_experiment_2 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_2_results(
    results_path=results_path,
    num_realizations=N_REALIZATIONS,
    prop_errors_threshold=PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 100

# %%
df
# Out:
# shape: (1_000, 8)
# ┌─────────────┬─────────────┬──────────┬────────────┬───────────┬────────┬────────────┬────────────┐
# │ random_stat ┆ frac_sample ┆ time     ┆ adj_accura ┆ ARI       ┆ status ┆ status_err ┆ sample_siz │
# │ e           ┆ _size       ┆ ---      ┆ cy         ┆ ---       ┆ ---    ┆ or         ┆ e_pct      │
# │ ---         ┆ ---         ┆ f64      ┆ ---        ┆ f64       ┆ str    ┆ ---        ┆ ---        │
# │ i64         ┆ f64         ┆          ┆ f64        ┆           ┆        ┆ bool       ┆ f64        │
# ╞═════════════╪═════════════╪══════════╪════════════╪═══════════╪════════╪════════════╪════════════╡
# │ 6863        ┆ 0.05        ┆ 0.639713 ┆ 0.513819   ┆ -0.003575 ┆ OK     ┆ false      ┆ 5.0        │
# │ 6863        ┆ 0.1         ┆ 0.499909 ┆ 0.826135   ┆ 0.509823  ┆ OK     ┆ false      ┆ 10.0       │
# │ 6863        ┆ 0.2         ┆ 0.58402  ┆ 0.824297   ┆ 0.506473  ┆ OK     ┆ false      ┆ 20.0       │
# │ 6863        ┆ 0.3         ┆ 0.637621 ┆ 0.825583   ┆ 0.509644  ┆ OK     ┆ false      ┆ 30.0       │
# │ 6863        ┆ 0.4         ┆ 0.709719 ┆ 0.822827   ┆ 0.500522  ┆ OK     ┆ false      ┆ 40.0       │
# │ …           ┆ …           ┆ …        ┆ …          ┆ …         ┆ …      ┆ …          ┆ …          │
# │ 30032       ┆ 0.5         ┆ 0.600472 ┆ 0.824114   ┆ 0.503672  ┆ OK     ┆ false      ┆ 50.0       │
# │ 30032       ┆ 0.6         ┆ 1.034418 ┆ 0.822827   ┆ 0.500522  ┆ OK     ┆ false      ┆ 60.0       │
# │ 30032       ┆ 0.7         ┆ 1.081895 ┆ 0.822827   ┆ 0.500522  ┆ OK     ┆ false      ┆ 70.0       │
# │ 30032       ┆ 0.8         ┆ 1.082509 ┆ 0.822827   ┆ 0.500522  ┆ OK     ┆ false      ┆ 80.0       │
# │ 30032       ┆ 0.9         ┆ 1.372516 ┆ 0.823194   ┆ 0.502006  ┆ OK     ┆ false      ┆ 90.0       │
# └─────────────┴─────────────┴──────────┴────────────┴───────────┴────────┴────────────┴────────────┘

# %%
df_avg
# Out:
# shape: (10, 8)
# ┌───────────────┬──────────┬──────────┬──────────┬──────────┬───────────┬──────────┬───────────────┐
# │ sample_size_p ┆ mean_acc ┆ std_acc  ┆ mean_ari ┆ std_ari  ┆ mean_time ┆ std_time ┆ prop_status_e │
# │ ct            ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---       ┆ ---      ┆ rror          │
# │ ---           ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64       ┆ f64      ┆ ---           │
# │ f64           ┆          ┆          ┆          ┆          ┆           ┆          ┆ f64           │
# ╞═══════════════╪══════════╪══════════╪══════════╪══════════╪═══════════╪══════════╪═══════════════╡
# │ 5.0           ┆ 0.802566 ┆ 0.078748 ┆ 0.467596 ┆ 0.129889 ┆ 0.72861   ┆ 0.15194  ┆ 0.0           │
# │ 10.0          ┆ 0.825027 ┆ 0.001417 ┆ 0.506913 ┆ 0.004374 ┆ 0.725183  ┆ 0.17712  ┆ 0.0           │
# │ 20.0          ┆ 0.824578 ┆ 0.001273 ┆ 0.505832 ┆ 0.003911 ┆ 0.706494  ┆ 0.165676 ┆ 0.0           │
# │ 30.0          ┆ 0.824435 ┆ 0.001323 ┆ 0.505375 ┆ 0.004075 ┆ 0.680417  ┆ 0.149337 ┆ 0.0           │
# │ 40.0          ┆ 0.824137 ┆ 0.001199 ┆ 0.504454 ┆ 0.003705 ┆ 0.682998  ┆ 0.138063 ┆ 0.0           │
# │ 50.0          ┆ 0.823854 ┆ 0.000959 ┆ 0.50347  ┆ 0.003158 ┆ 0.712496  ┆ 0.138729 ┆ 0.0           │
# │ 60.0          ┆ 0.823744 ┆ 0.000981 ┆ 0.50327  ┆ 0.003227 ┆ 0.742827  ┆ 0.134588 ┆ 0.0           │
# │ 70.0          ┆ 0.823582 ┆ 0.000927 ┆ 0.502821 ┆ 0.00309  ┆ 0.78246   ┆ 0.142338 ┆ 0.0           │
# │ 80.0          ┆ 0.82332  ┆ 0.000812 ┆ 0.501982 ┆ 0.002596 ┆ 0.86864   ┆ 0.181069 ┆ 0.0           │
# │ 90.0          ┆ 0.823009 ┆ 0.000564 ┆ 0.501115 ┆ 0.001842 ┆ 0.894809  ┆ 0.161887 ┆ 0.0           │
# └───────────────┴──────────┴──────────┴──────────┴──────────┴───────────┴──────────┴───────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.05
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.05
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.7737991434174702, 0.8737991434174703)
# ylim_ari: (0.45337023227163115, 0.5533702322716312)
# ylim_time: (-1.2731035566329956, 2.7268964433670044)

# %%
error_style = None
plot_filename = f'plot_results_exp_2_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'fill'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'bar'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df, 
    df_avg=df_avg,
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)

# %%
error_style = 'boxplot'
plot_filename = f'plot_results_exp_2_{DATA_ID}_error_{error_style}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_2_results(
    df=df,
    df_avg=df_avg, 
    data_name=DATA_ID, 
    num_realizations=N_REALIZATIONS,
    error_style=error_style,
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,
    save_path=save_path
)
