# %%
import os, sys

# %%
# Define el ID del experimento que quieres analizar
DATA_ID = 'simulation_6' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_3', DATA_ID)
filename = f'results_exp_3_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_3_results, plot_experiment_3_results
from config.config_experiment_3 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_3_results(
    results_path = results_path, 
    prop_errors_threshold = PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 70

# %%
df
# Out:
# shape: (1_120, 9)
# ┌────────────┬──────────┬────────────┬────────────┬───┬──────────┬────────┬────────────┬───────────┐
# │ random_sta ┆ n_splits ┆ frac_sampl ┆ time       ┆ … ┆ ARI      ┆ status ┆ status_err ┆ sample_si │
# │ te         ┆ ---      ┆ e_size     ┆ ---        ┆   ┆ ---      ┆ ---    ┆ or         ┆ ze_pct    │
# │ ---        ┆ i64      ┆ ---        ┆ f64        ┆   ┆ f64      ┆ str    ┆ ---        ┆ ---       │
# │ i64        ┆          ┆ f64        ┆            ┆   ┆          ┆        ┆ bool       ┆ f64       │
# ╞════════════╪══════════╪════════════╪════════════╪═══╪══════════╪════════╪════════════╪═══════════╡
# │ 6863       ┆ 5        ┆ 0.005      ┆ 91.790312  ┆ … ┆ 0.648936 ┆ OK     ┆ false      ┆ 0.5       │
# │ 6863       ┆ 5        ┆ 0.05       ┆ 95.749318  ┆ … ┆ 0.619151 ┆ OK     ┆ false      ┆ 5.0       │
# │ 6863       ┆ 5        ┆ 0.1        ┆ 112.779861 ┆ … ┆ 0.525394 ┆ OK     ┆ false      ┆ 10.0      │
# │ 6863       ┆ 5        ┆ 0.15       ┆ 148.433125 ┆ … ┆ 0.527473 ┆ OK     ┆ false      ┆ 15.0      │
# │ 6863       ┆ 10       ┆ 0.005      ┆ 92.556665  ┆ … ┆ 0.652454 ┆ OK     ┆ false      ┆ 0.5       │
# │ …          ┆ …        ┆ …          ┆ …          ┆ … ┆ …        ┆ …      ┆ …          ┆ …         │
# │ 47646      ┆ 20       ┆ 0.15       ┆ 101.92489  ┆ … ┆ 0.558837 ┆ OK     ┆ false      ┆ 15.0      │
# │ 47646      ┆ 40       ┆ 0.005      ┆ 102.283632 ┆ … ┆ 0.570568 ┆ OK     ┆ false      ┆ 0.5       │
# │ 47646      ┆ 40       ┆ 0.05       ┆ 99.059932  ┆ … ┆ 0.615804 ┆ OK     ┆ false      ┆ 5.0       │
# │ 47646      ┆ 40       ┆ 0.1        ┆ 97.13711   ┆ … ┆ 0.612961 ┆ OK     ┆ false      ┆ 10.0      │
# │ 47646      ┆ 40       ┆ 0.15       ┆ 98.390903  ┆ … ┆ 0.604174 ┆ OK     ┆ false      ┆ 15.0      │
# └────────────┴──────────┴────────────┴────────────┴───┴──────────┴────────┴────────────┴───────────┘

# %%
df_avg
# Out:
# shape: (16, 9)
# ┌──────────┬────────────┬──────────┬──────────┬───┬──────────┬────────────┬───────────┬────────────┐
# │ n_splits ┆ sample_siz ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time  ┆ std_time  ┆ prop_statu │
# │ ---      ┆ e_pct      ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---        ┆ ---       ┆ s_error    │
# │ i64      ┆ ---        ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64        ┆ f64       ┆ ---        │
# │          ┆ f64        ┆          ┆          ┆   ┆          ┆            ┆           ┆ f64        │
# ╞══════════╪════════════╪══════════╪══════════╪═══╪══════════╪════════════╪═══════════╪════════════╡
# │ 5        ┆ 0.5        ┆ 0.833552 ┆ 0.043437 ┆ … ┆ 0.065627 ┆ 95.892305  ┆ 13.189454 ┆ 0.0        │
# │ 5        ┆ 5.0        ┆ 0.806475 ┆ 0.048563 ┆ … ┆ 0.068428 ┆ 100.26137  ┆ 13.29759  ┆ 0.0        │
# │ 5        ┆ 10.0       ┆ 0.810354 ┆ 0.040551 ┆ … ┆ 0.044753 ┆ 123.274328 ┆ 16.314013 ┆ 0.0        │
# │ 5        ┆ 15.0       ┆ 0.79894  ┆ 0.046544 ┆ … ┆ 0.06924  ┆ 164.726286 ┆ 21.333567 ┆ 0.0        │
# │ 10       ┆ 0.5        ┆ 0.842325 ┆ 0.029767 ┆ … ┆ 0.045915 ┆ 97.236724  ┆ 13.300004 ┆ 0.0        │
# │ …        ┆ …          ┆ …        ┆ …        ┆ … ┆ …        ┆ …          ┆ …         ┆ …          │
# │ 20       ┆ 15.0       ┆ 0.827732 ┆ 0.013886 ┆ … ┆ 0.021671 ┆ 105.599133 ┆ 13.552412 ┆ 0.0        │
# │ 40       ┆ 0.5        ┆ 0.817599 ┆ 0.017904 ┆ … ┆ 0.027838 ┆ 105.480388 ┆ 13.498583 ┆ 0.0        │
# │ 40       ┆ 5.0        ┆ 0.845098 ┆ 0.00925  ┆ … ┆ 0.016237 ┆ 103.029119 ┆ 14.544745 ┆ 0.0        │
# │ 40       ┆ 10.0       ┆ 0.839507 ┆ 0.009065 ┆ … ┆ 0.015439 ┆ 101.181905 ┆ 14.13049  ┆ 0.0        │
# │ 40       ┆ 15.0       ┆ 0.839052 ┆ 0.007084 ┆ … ┆ 0.012272 ┆ 102.467887 ┆ 14.217479 ┆ 0.0        │
# └──────────┴────────────┴──────────┴──────────┴───┴──────────┴────────────┴───────────┴────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.1
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.1
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.7097439139708828, 0.9497506574576888)
# ylim_ari: (0.4639775555751232, 0.7255975004753469)
# ylim_time: (78.16763360206812, 125.48215878643919)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style=None,  
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_fill.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='fill', 
    ylim_acc=ylim_acc,
    ylim_ari=ylim_ari,
    #ylim_time=(70, 190),   
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_bar.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='bar',   
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_boxplot.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='boxplot', 
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)
