# %%
import os, sys
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
script_path = os.getcwd()
project_path = os.path.abspath(os.path.join(script_path, '..', '..', '..'))

results_exp_3a_dir = os.path.join(project_path, 'results', 'experiment_3a')
results_exp_3a_path = os.path.join(results_exp_3a_dir, 'master_table_exp_3a.parquet')

results_exp_3b_dir = os.path.join(project_path, 'results', 'experiment_3b')
results_exp_3b_path = os.path.join(results_exp_3b_dir, 'master_table_exp_3b.parquet')

# %%
df_results_exp_3a = pl.read_parquet(results_exp_3a_path)
df_results_exp_3b = pl.read_parquet(results_exp_3b_path)

# %%
df_results_exp_3a
# Out:
# shape: (27, 38)
# ┌──────────┬────────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ n_splits ┆ sample_siz ┆ mean_acc ┆ std_acc  ┆ … ┆ imbalance_ ┆ imbalance ┆ is_balanc ┆ convex_ge │
# │ ---      ┆ e_pct      ┆ ---      ┆ ---      ┆   ┆ ratio      ┆ _ratio_st ┆ ed        ┆ ometry    │
# │ i64      ┆ ---        ┆ f64      ┆ f64      ┆   ┆ ---        ┆ d         ┆ ---       ┆ ---       │
# │          ┆ f64        ┆          ┆          ┆   ┆ f64        ┆ ---       ┆ bool      ┆ bool      │
# │          ┆            ┆          ┆          ┆   ┆            ┆ f64       ┆           ┆           │
# ╞══════════╪════════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 3        ┆ 20.0       ┆ 0.8558   ┆ 0.106104 ┆ … ┆ 1.0003     ┆ 0.0       ┆ true      ┆ true      │
# │ 3        ┆ 30.0       ┆ 0.850285 ┆ 0.113762 ┆ … ┆ 1.0003     ┆ 0.0       ┆ true      ┆ true      │
# ...

# %%
df_results_exp_3b
# Out:
# shape: (18, 38)
# ┌──────────┬────────────┬──────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ n_splits ┆ sample_siz ┆ mean_acc ┆ std_acc  ┆ … ┆ imbalance_ ┆ imbalance ┆ is_balanc ┆ convex_ge │
# │ ---      ┆ e_pct      ┆ ---      ┆ ---      ┆   ┆ ratio      ┆ _ratio_st ┆ ed        ┆ ometry    │
# │ i64      ┆ ---        ┆ f64      ┆ f64      ┆   ┆ ---        ┆ d         ┆ ---       ┆ ---       │
# │          ┆ f64        ┆          ┆          ┆   ┆ f64        ┆ ---       ┆ bool      ┆ bool      │
# │          ┆            ┆          ┆          ┆   ┆            ┆ f64       ┆           ┆           │
# ╞══════════╪════════════╪══════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 3        ┆ 20.0       ┆ 0.889775 ┆ 0.015109 ┆ … ┆ 1.0003     ┆ 0.0       ┆ true      ┆ true      │
# │ 3        ┆ 30.0       ┆ 0.887796 ┆ 0.011809 ┆ … ┆ 1.0003     ┆ 0.0       ┆ true      ┆ true      │
# ...
