# %%
import os, sys

# %%
# Define el ID del experimento que quieres analizar
DATA_ID = 'simulation_4' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_3', DATA_ID)
filename = f'results_exp_3_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_3_results, plot_experiment_3_results
from config.config_experiment_3 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_3_results(
    results_path = results_path, 
    prop_errors_threshold = PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 50

# %%
df
# Out:
# shape: (600, 9)
# ┌────────────┬──────────┬────────────┬────────────┬───┬──────────┬────────┬────────────┬───────────┐
# │ random_sta ┆ n_splits ┆ frac_sampl ┆ time       ┆ … ┆ ARI      ┆ status ┆ status_err ┆ sample_si │
# │ te         ┆ ---      ┆ e_size     ┆ ---        ┆   ┆ ---      ┆ ---    ┆ or         ┆ ze_pct    │
# │ ---        ┆ i64      ┆ ---        ┆ f64        ┆   ┆ f64      ┆ str    ┆ ---        ┆ ---       │
# │ i64        ┆          ┆ f64        ┆            ┆   ┆          ┆        ┆ bool       ┆ f64       │
# ╞════════════╪══════════╪════════════╪════════════╪═══╪══════════╪════════╪════════════╪═══════════╡
# │ 3431       ┆ 5        ┆ 0.0005     ┆ 687.000383 ┆ … ┆ 0.613064 ┆ OK     ┆ false      ┆ 0.05      │
# │ 3431       ┆ 5        ┆ 0.005      ┆ 365.186223 ┆ … ┆ 0.604888 ┆ OK     ┆ false      ┆ 0.5       │
# │ 3431       ┆ 5        ┆ 0.01       ┆ 638.506651 ┆ … ┆ 0.550549 ┆ OK     ┆ false      ┆ 1.0       │
# │ 3431       ┆ 10       ┆ 0.0005     ┆ 653.131409 ┆ … ┆ 0.53228  ┆ OK     ┆ false      ┆ 0.05      │
# │ 3431       ┆ 10       ┆ 0.005      ┆ 650.295925 ┆ … ┆ 0.594828 ┆ OK     ┆ false      ┆ 0.5       │
# │ …          ┆ …        ┆ …          ┆ …          ┆ … ┆ …        ┆ …      ┆ …          ┆ …         │
# │ 13556      ┆ 20       ┆ 0.005      ┆ 360.434938 ┆ … ┆ 0.600814 ┆ OK     ┆ false      ┆ 0.5       │
# │ 13556      ┆ 20       ┆ 0.01       ┆ 410.459798 ┆ … ┆ 0.581388 ┆ OK     ┆ false      ┆ 1.0       │
# │ 13556      ┆ 40       ┆ 0.0005     ┆ 385.496031 ┆ … ┆ 0.4533   ┆ OK     ┆ false      ┆ 0.05      │
# │ 13556      ┆ 40       ┆ 0.005      ┆ 413.498298 ┆ … ┆ 0.591644 ┆ OK     ┆ false      ┆ 0.5       │
# │ 13556      ┆ 40       ┆ 0.01       ┆ 466.221599 ┆ … ┆ 0.584333 ┆ OK     ┆ false      ┆ 1.0       │
# └────────────┴──────────┴────────────┴────────────┴───┴──────────┴────────┴────────────┴───────────┘

# %%
df_avg
# Out:
# shape: (12, 9)
# ┌──────────┬────────────┬───────────┬──────────┬───┬──────────┬────────────┬───────────┬───────────┐
# │ n_splits ┆ sample_siz ┆ mean_acc  ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time  ┆ std_time  ┆ prop_stat │
# │ ---      ┆ e_pct      ┆ ---       ┆ ---      ┆   ┆ ---      ┆ ---        ┆ ---       ┆ us_error  │
# │ i64      ┆ ---        ┆ f64       ┆ f64      ┆   ┆ f64      ┆ f64        ┆ f64       ┆ ---       │
# │          ┆ f64        ┆           ┆          ┆   ┆          ┆            ┆           ┆ f64       │
# ╞══════════╪════════════╪═══════════╪══════════╪═══╪══════════╪════════════╪═══════════╪═══════════╡
# │ 5        ┆ 0.05       ┆ 0.805139  ┆ 0.052001 ┆ … ┆ 0.066871 ┆ 693.86803  ┆ 193.61933 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 7         ┆           │
# │ 5        ┆ 0.5        ┆ 0.800213  ┆ 0.040538 ┆ … ┆ 0.05105  ┆ 687.968877 ┆ 192.05233 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 6         ┆           │
# │ 5        ┆ 1.0        ┆ 0.779335  ┆ 0.049252 ┆ … ┆ 0.062588 ┆ 712.868148 ┆ 181.42708 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 3         ┆           │
# │ 10       ┆ 0.05       ┆ 0.8064271 ┆ 0.033648 ┆ … ┆ 0.043654 ┆ 717.055761 ┆ 215.75631 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 8         ┆           │
# │ 10       ┆ 0.5        ┆ 0.80789   ┆ 0.050206 ┆ … ┆ 0.040379 ┆ 709.213088 ┆ 203.08816 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 2         ┆           │
# │ …        ┆ …          ┆ …         ┆ …        ┆ … ┆ …        ┆ …          ┆ …         ┆ …         │
# │ 20       ┆ 0.5        ┆ 0.821614  ┆ 0.013708 ┆ … ┆ 0.022271 ┆ 700.71131  ┆ 164.61223 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 5         ┆           │
# │ 20       ┆ 1.0        ┆ 0.816116  ┆ 0.023399 ┆ … ┆ 0.028031 ┆ 706.466791 ┆ 208.68725 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 7         ┆           │
# │ 40       ┆ 0.05       ┆ 0.720583  ┆ 0.02711  ┆ … ┆ 0.033273 ┆ 757.911232 ┆ 325.91998 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 2         ┆           │
# │ 40       ┆ 0.5        ┆ 0.822077  ┆ 0.012209 ┆ … ┆ 0.019448 ┆ 745.792421 ┆ 179.10291 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 9         ┆           │
# │ 40       ┆ 1.0        ┆ 0.822034  ┆ 0.008921 ┆ … ┆ 0.014721 ┆ 716.006679 ┆ 167.73234 ┆ 0.0       │
# │          ┆            ┆           ┆          ┆   ┆          ┆            ┆ 2         ┆           │
# └──────────┴────────────┴───────────┴──────────┴───┴──────────┴────────────┴───────────┴───────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.12
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.15
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.6566796232449222, 0.9576376967550778)
# ylim_ari: (0.37656591040941473, 0.7502184553426519)
# ylim_time: (514.3009085514341, 907.780327358028)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style=None,  
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_fill.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='fill', 
    ylim_acc=ylim_acc,
    ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_bar.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='bar',   
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_boxplot.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='boxplot', 
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)
