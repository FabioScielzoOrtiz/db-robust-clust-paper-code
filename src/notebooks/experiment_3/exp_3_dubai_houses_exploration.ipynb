# %%
import os, sys

# %%
# Define el ID del experimento que quieres analizar
DATA_ID = 'dubai_houses' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_3', DATA_ID)
filename = f'results_exp_3_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_3_results, plot_experiment_3_results
from config.config_experiment_3 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_3_results(
    results_path = results_path, 
    prop_errors_threshold = PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 100

# %%
df
# Out:
# shape: (2_100, 9)
# ┌─────────────┬──────────┬────────────┬──────────┬───┬──────────┬────────┬────────────┬────────────┐
# │ random_stat ┆ n_splits ┆ frac_sampl ┆ time     ┆ … ┆ ARI      ┆ status ┆ status_err ┆ sample_siz │
# │ e           ┆ ---      ┆ e_size     ┆ ---      ┆   ┆ ---      ┆ ---    ┆ or         ┆ e_pct      │
# │ ---         ┆ i64      ┆ ---        ┆ f64      ┆   ┆ f64      ┆ str    ┆ ---        ┆ ---        │
# │ i64         ┆          ┆ f64        ┆          ┆   ┆          ┆        ┆ bool       ┆ f64        │
# ╞═════════════╪══════════╪════════════╪══════════╪═══╪══════════╪════════╪════════════╪════════════╡
# │ 6863        ┆ 5        ┆ 0.3        ┆ 3.064028 ┆ … ┆ 0.480021 ┆ OK     ┆ false      ┆ 30.0       │
# │ 6863        ┆ 5        ┆ 0.4        ┆ 2.70001  ┆ … ┆ 0.497562 ┆ OK     ┆ false      ┆ 40.0       │
# │ 6863        ┆ 5        ┆ 0.5        ┆ 2.766968 ┆ … ┆ 0.500522 ┆ OK     ┆ false      ┆ 50.0       │
# │ 6863        ┆ 5        ┆ 0.6        ┆ 2.516343 ┆ … ┆ 0.502365 ┆ OK     ┆ false      ┆ 60.0       │
# │ 6863        ┆ 5        ┆ 0.7        ┆ 2.655874 ┆ … ┆ 0.509823 ┆ OK     ┆ false      ┆ 70.0       │
# │ …           ┆ …        ┆ …          ┆ …        ┆ … ┆ …        ┆ …      ┆ …          ┆ …          │
# │ 30032       ┆ 15       ┆ 0.5        ┆ 8.295509 ┆ … ┆ 0.443586 ┆ OK     ┆ false      ┆ 50.0       │
# │ 30032       ┆ 15       ┆ 0.6        ┆ 6.181326 ┆ … ┆ 0.501414 ┆ OK     ┆ false      ┆ 60.0       │
# │ 30032       ┆ 15       ┆ 0.7        ┆ 5.904716 ┆ … ┆ 0.496446 ┆ OK     ┆ false      ┆ 70.0       │
# │ 30032       ┆ 15       ┆ 0.8        ┆ 6.412117 ┆ … ┆ 0.508504 ┆ OK     ┆ false      ┆ 80.0       │
# │ 30032       ┆ 15       ┆ 0.9        ┆ 7.010754 ┆ … ┆ 0.502365 ┆ OK     ┆ false      ┆ 90.0       │
# └─────────────┴──────────┴────────────┴──────────┴───┴──────────┴────────┴────────────┴────────────┘

# %%
df_avg
# Out:
# shape: (21, 9)
# ┌──────────┬─────────────┬──────────┬──────────┬───┬──────────┬───────────┬──────────┬─────────────┐
# │ n_splits ┆ sample_size ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time ┆ std_time ┆ prop_status │
# │ ---      ┆ _pct        ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---      ┆ _error      │
# │ i64      ┆ ---         ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64       ┆ f64      ┆ ---         │
# │          ┆ f64         ┆          ┆          ┆   ┆          ┆           ┆          ┆ f64         │
# ╞══════════╪═════════════╪══════════╪══════════╪═══╪══════════╪═══════════╪══════════╪═════════════╡
# │ 5        ┆ 30.0        ┆ 0.791646 ┆ 0.058254 ┆ … ┆ 0.110992 ┆ 2.894147  ┆ 0.451443 ┆ 0.0         │
# │ 5        ┆ 40.0        ┆ 0.789762 ┆ 0.071705 ┆ … ┆ 0.117429 ┆ 2.822962  ┆ 0.431473 ┆ 0.0         │
# │ 5        ┆ 50.0        ┆ 0.795302 ┆ 0.066482 ┆ … ┆ 0.111894 ┆ 2.821132  ┆ 0.441206 ┆ 0.0         │
# │ 5        ┆ 60.0        ┆ 0.814973 ┆ 0.038053 ┆ … ┆ 0.076574 ┆ 2.742648  ┆ 0.40818  ┆ 0.0         │
# │ 5        ┆ 70.0        ┆ 0.810078 ┆ 0.053156 ┆ … ┆ 0.087794 ┆ 2.78288   ┆ 0.400785 ┆ 0.0         │
# │ …        ┆ …           ┆ …        ┆ …        ┆ … ┆ …        ┆ …         ┆ …        ┆ …           │
# │ 15       ┆ 50.0        ┆ 0.778526 ┆ 0.028396 ┆ … ┆ 0.045068 ┆ 7.038828  ┆ 0.935325 ┆ 0.0         │
# │ 15       ┆ 60.0        ┆ 0.792137 ┆ 0.023007 ┆ … ┆ 0.036201 ┆ 7.085954  ┆ 1.07171  ┆ 0.0         │
# │ 15       ┆ 70.0        ┆ 0.803553 ┆ 0.017399 ┆ … ┆ 0.026401 ┆ 6.976978  ┆ 1.023317 ┆ 0.0         │
# │ 15       ┆ 80.0        ┆ 0.811092 ┆ 0.013599 ┆ … ┆ 0.019522 ┆ 7.078311  ┆ 1.078054 ┆ 0.0         │
# │ 15       ┆ 90.0        ┆ 0.817063 ┆ 0.013506 ┆ … ┆ 0.023062 ┆ 7.093237  ┆ 0.996143 ┆ 0.0         │
# └──────────┴─────────────┴──────────┴──────────┴───┴──────────┴───────────┴──────────┴─────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.10
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.12
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.6692424187868967, 0.9378639206261651)
# ylim_ari: (0.29636232596191, 0.6462624901183402)
# ylim_time: (-5.724974163140732, 15.567640879716354)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style=None,  
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_fill.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='fill', 
    ylim_acc=ylim_acc,
    ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_bar.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='bar',   
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_multifold_{DATA_ID}_error_boxplot.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='boxplot', 
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)
