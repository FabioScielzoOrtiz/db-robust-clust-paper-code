# %%
import os, sys

# %%
# Define el ID del experimento que quieres analizar
DATA_ID = 'simulation_2' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_3', DATA_ID)
filename = f'results_exp_3_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_3_results, plot_experiment_3_results
from config.config_experiment_3 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_3_results(
    results_path = results_path, 
    prop_errors_threshold = PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 91

# %%
df
# Out:
# shape: (1_456, 9)
# ┌────────────┬──────────┬────────────┬────────────┬───┬──────────┬────────┬────────────┬───────────┐
# │ random_sta ┆ n_splits ┆ frac_sampl ┆ time       ┆ … ┆ ARI      ┆ status ┆ status_err ┆ sample_si │
# │ te         ┆ ---      ┆ e_size     ┆ ---        ┆   ┆ ---      ┆ ---    ┆ or         ┆ ze_pct    │
# │ ---        ┆ i64      ┆ ---        ┆ f64        ┆   ┆ f64      ┆ str    ┆ ---        ┆ ---       │
# │ i64        ┆          ┆ f64        ┆            ┆   ┆          ┆        ┆ bool       ┆ f64       │
# ╞════════════╪══════════╪════════════╪════════════╪═══╪══════════╪════════╪════════════╪═══════════╡
# │ 95135      ┆ 5        ┆ 0.005      ┆ 76.164622  ┆ … ┆ 0.698961 ┆ OK     ┆ false      ┆ 0.5       │
# │ 95135      ┆ 5        ┆ 0.05       ┆ 78.685618  ┆ … ┆ 0.709637 ┆ OK     ┆ false      ┆ 5.0       │
# │ 95135      ┆ 5        ┆ 0.1        ┆ 75.483843  ┆ … ┆ 0.709593 ┆ OK     ┆ false      ┆ 10.0      │
# │ 95135      ┆ 5        ┆ 0.25       ┆ 109.450257 ┆ … ┆ 0.704423 ┆ OK     ┆ false      ┆ 25.0      │
# │ 95135      ┆ 10       ┆ 0.005      ┆ 77.149173  ┆ … ┆ 0.660051 ┆ OK     ┆ false      ┆ 0.5       │
# │ …          ┆ …        ┆ …          ┆ …          ┆ … ┆ …        ┆ …      ┆ …          ┆ …         │
# │ 30032      ┆ 20       ┆ 0.25       ┆ 74.083613  ┆ … ┆ 0.707824 ┆ OK     ┆ false      ┆ 25.0      │
# │ 30032      ┆ 40       ┆ 0.005      ┆ 86.909447  ┆ … ┆ 0.41363  ┆ OK     ┆ false      ┆ 0.5       │
# │ 30032      ┆ 40       ┆ 0.05       ┆ 87.159249  ┆ … ┆ 0.698571 ┆ OK     ┆ false      ┆ 5.0       │
# │ 30032      ┆ 40       ┆ 0.1        ┆ 82.725585  ┆ … ┆ 0.702806 ┆ OK     ┆ false      ┆ 10.0      │
# │ 30032      ┆ 40       ┆ 0.25       ┆ 78.367342  ┆ … ┆ 0.705893 ┆ OK     ┆ false      ┆ 25.0      │
# └────────────┴──────────┴────────────┴────────────┴───┴──────────┴────────┴────────────┴───────────┘

# %%
df_avg
# Out:
# shape: (16, 9)
# ┌──────────┬─────────────┬──────────┬──────────┬───┬──────────┬───────────┬───────────┬────────────┐
# │ n_splits ┆ sample_size ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time ┆ std_time  ┆ prop_statu │
# │ ---      ┆ _pct        ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---       ┆ s_error    │
# │ i64      ┆ ---         ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64       ┆ f64       ┆ ---        │
# │          ┆ f64         ┆          ┆          ┆   ┆          ┆           ┆           ┆ f64        │
# ╞══════════╪═════════════╪══════════╪══════════╪═══╪══════════╪═══════════╪═══════════╪════════════╡
# │ 5        ┆ 0.5         ┆ 0.862182 ┆ 0.037178 ┆ … ┆ 0.060486 ┆ 58.902261 ┆ 13.553474 ┆ 0.0        │
# │ 5        ┆ 5.0         ┆ 0.870161 ┆ 0.026039 ┆ … ┆ 0.051067 ┆ 58.127094 ┆ 13.370652 ┆ 0.0        │
# │ 5        ┆ 10.0        ┆ 0.871348 ┆ 0.02499  ┆ … ┆ 0.045649 ┆ 60.840425 ┆ 13.738768 ┆ 0.0        │
# │ 5        ┆ 25.0        ┆ 0.870298 ┆ 0.024829 ┆ … ┆ 0.046196 ┆ 91.953765 ┆ 19.183518 ┆ 0.0        │
# │ 10       ┆ 0.5         ┆ 0.861493 ┆ 0.016417 ┆ … ┆ 0.03448  ┆ 61.000999 ┆ 14.187424 ┆ 0.0        │
# │ …        ┆ …           ┆ …        ┆ …        ┆ … ┆ …        ┆ …         ┆ …         ┆ …          │
# │ 20       ┆ 25.0        ┆ 0.874994 ┆ 0.006436 ┆ … ┆ 0.014098 ┆ 63.038905 ┆ 14.268273 ┆ 0.0        │
# │ 40       ┆ 0.5         ┆ 0.725041 ┆ 0.018813 ┆ … ┆ 0.030768 ┆ 74.311112 ┆ 17.605899 ┆ 0.0        │
# │ 40       ┆ 5.0         ┆ 0.875098 ┆ 0.001719 ┆ … ┆ 0.00372  ┆ 72.537801 ┆ 17.189206 ┆ 0.0        │
# │ 40       ┆ 10.0        ┆ 0.875458 ┆ 0.001206 ┆ … ┆ 0.002607 ┆ 70.046471 ┆ 16.649164 ┆ 0.0        │
# │ 40       ┆ 25.0        ┆ 0.875921 ┆ 0.000858 ┆ … ┆ 0.001838 ┆ 66.268235 ┆ 15.529629 ┆ 0.0        │
# └──────────┴─────────────┴──────────┴──────────┴───┴──────────┴───────────┴───────────┴────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.05
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.05
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.8153033472057021, 0.933617202244847)
# ylim_ari: (0.6327602566597048, 0.7687885428213943)
# ylim_time: (38.58719265178053, 87.51645602650652)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style=None,  
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_fill.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='fill', 
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_bar.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='bar',   
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_boxplot.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='boxplot', 
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)
