# %%
import os, sys

# %%
# Define el ID del experimento que quieres analizar
DATA_ID = 'heart_disease' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_3', DATA_ID)
filename = f'results_exp_3_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_3_results, plot_experiment_3_results
from config.config_experiment_3 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_3_results(
    results_path = results_path, 
    prop_errors_threshold = PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 100

# %%
df
# Out:
# shape: (3_200, 9)
# ┌─────────────┬──────────┬────────────┬──────────┬───┬──────────┬────────┬────────────┬────────────┐
# │ random_stat ┆ n_splits ┆ frac_sampl ┆ time     ┆ … ┆ ARI      ┆ status ┆ status_err ┆ sample_siz │
# │ e           ┆ ---      ┆ e_size     ┆ ---      ┆   ┆ ---      ┆ ---    ┆ or         ┆ e_pct      │
# │ ---         ┆ i64      ┆ ---        ┆ f64      ┆   ┆ f64      ┆ str    ┆ ---        ┆ ---        │
# │ i64         ┆          ┆ f64        ┆          ┆   ┆          ┆        ┆ bool       ┆ f64        │
# ╞═════════════╪══════════╪════════════╪══════════╪═══╪══════════╪════════╪════════════╪════════════╡
# │ 6863        ┆ 3        ┆ 0.2        ┆ 2.52125  ┆ … ┆ 0.112151 ┆ OK     ┆ false      ┆ 20.0       │
# │ 6863        ┆ 3        ┆ 0.3        ┆ 2.512587 ┆ … ┆ 0.291473 ┆ OK     ┆ false      ┆ 30.0       │
# │ 6863        ┆ 3        ┆ 0.4        ┆ 2.552802 ┆ … ┆ 0.022803 ┆ OK     ┆ false      ┆ 40.0       │
# │ 6863        ┆ 3        ┆ 0.5        ┆ 2.916636 ┆ … ┆ 0.25599  ┆ OK     ┆ false      ┆ 50.0       │
# │ 6863        ┆ 3        ┆ 0.6        ┆ 2.874516 ┆ … ┆ 0.210122 ┆ OK     ┆ false      ┆ 60.0       │
# │ …           ┆ …        ┆ …          ┆ …        ┆ … ┆ …        ┆ …      ┆ …          ┆ …          │
# │ 30032       ┆ 10       ┆ 0.5        ┆ 5.038309 ┆ … ┆ 0.053357 ┆ OK     ┆ false      ┆ 50.0       │
# │ 30032       ┆ 10       ┆ 0.6        ┆ 5.031717 ┆ … ┆ 0.008582 ┆ OK     ┆ false      ┆ 60.0       │
# │ 30032       ┆ 10       ┆ 0.7        ┆ 5.049946 ┆ … ┆ 0.007909 ┆ OK     ┆ false      ┆ 70.0       │
# │ 30032       ┆ 10       ┆ 0.8        ┆ 5.038505 ┆ … ┆ 0.035601 ┆ OK     ┆ false      ┆ 80.0       │
# │ 30032       ┆ 10       ┆ 0.9        ┆ 5.026074 ┆ … ┆ 0.021396 ┆ OK     ┆ false      ┆ 90.0       │
# └─────────────┴──────────┴────────────┴──────────┴───┴──────────┴────────┴────────────┴────────────┘

# %%
df_avg
# Out:
# shape: (32, 9)
# ┌──────────┬─────────────┬──────────┬──────────┬───┬──────────┬───────────┬──────────┬─────────────┐
# │ n_splits ┆ sample_size ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time ┆ std_time ┆ prop_status │
# │ ---      ┆ _pct        ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---      ┆ _error      │
# │ i64      ┆ ---         ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64       ┆ f64      ┆ ---         │
# │          ┆ f64         ┆          ┆          ┆   ┆          ┆           ┆          ┆ f64         │
# ╞══════════╪═════════════╪══════════╪══════════╪═══╪══════════╪═══════════╪══════════╪═════════════╡
# │ 3        ┆ 20.0        ┆ 0.62101  ┆ 0.07319  ┆ … ┆ 0.078272 ┆ 2.146862  ┆ 0.457007 ┆ 0.0         │
# │ 3        ┆ 30.0        ┆ 0.622896 ┆ 0.078229 ┆ … ┆ 0.086286 ┆ 2.110856  ┆ 0.457615 ┆ 0.0         │
# │ 3        ┆ 40.0        ┆ 0.635455 ┆ 0.073459 ┆ … ┆ 0.0853   ┆ 2.149413  ┆ 0.462148 ┆ 0.0         │
# │ 3        ┆ 50.0        ┆ 0.645219 ┆ 0.081469 ┆ … ┆ 0.091956 ┆ 2.179837  ┆ 0.509914 ┆ 0.0         │
# │ 3        ┆ 60.0        ┆ 0.66138  ┆ 0.081808 ┆ … ┆ 0.101191 ┆ 2.144264  ┆ 0.509954 ┆ 0.0         │
# │ …        ┆ …           ┆ …        ┆ …        ┆ … ┆ …        ┆ …         ┆ …        ┆ …           │
# │ 10       ┆ 50.0        ┆ 0.617374 ┆ 0.056972 ┆ … ┆ 0.057404 ┆ 5.656775  ┆ 1.496991 ┆ 0.0         │
# │ 10       ┆ 60.0        ┆ 0.619562 ┆ 0.056429 ┆ … ┆ 0.059439 ┆ 5.540577  ┆ 0.996362 ┆ 0.0         │
# │ 10       ┆ 70.0        ┆ 0.626532 ┆ 0.063161 ┆ … ┆ 0.068443 ┆ 5.638731  ┆ 1.009984 ┆ 0.0         │
# │ 10       ┆ 80.0        ┆ 0.62532  ┆ 0.059203 ┆ … ┆ 0.063201 ┆ 5.555063  ┆ 0.927483 ┆ 0.0         │
# │ 10       ┆ 90.0        ┆ 0.625623 ┆ 0.063537 ┆ … ┆ 0.069122 ┆ 5.476643  ┆ 0.93518  ┆ 0.0         │
# └──────────┴─────────────┴──────────┴──────────┴───┴──────────┴───────────┴──────────┴─────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.1
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.1
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.46560888556984287, 0.8047614848005276)
# ylim_ari: (-0.09467248756472368, 0.27389341645149423)
# ylim_time: (-6.6313521600478635, 14.658690502714489)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style=None,  
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_fill.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='fill', 
    ylim_acc=ylim_acc,
    ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_bar.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='bar',   
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_boxplot.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='boxplot', 
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)
