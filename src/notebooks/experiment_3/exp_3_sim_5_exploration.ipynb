# %%
import os, sys

# %%
# Define el ID del experimento que quieres analizar
DATA_ID = 'simulation_5' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_3', DATA_ID)
filename = f'results_exp_3_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_3_results, plot_experiment_3_results
from config.config_experiment_3 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_3_results(
    results_path = results_path, 
    prop_errors_threshold = PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 70

# %%
df
# Out:
# shape: (1_120, 9)
# ┌────────────┬──────────┬────────────┬────────────┬───┬──────────┬────────┬────────────┬───────────┐
# │ random_sta ┆ n_splits ┆ frac_sampl ┆ time       ┆ … ┆ ARI      ┆ status ┆ status_err ┆ sample_si │
# │ te         ┆ ---      ┆ e_size     ┆ ---        ┆   ┆ ---      ┆ ---    ┆ or         ┆ ze_pct    │
# │ ---        ┆ i64      ┆ ---        ┆ f64        ┆   ┆ f64      ┆ str    ┆ ---        ┆ ---       │
# │ i64        ┆          ┆ f64        ┆            ┆   ┆          ┆        ┆ bool       ┆ f64       │
# ╞════════════╪══════════╪════════════╪════════════╪═══╪══════════╪════════╪════════════╪═══════════╡
# │ 6863       ┆ 5        ┆ 0.005      ┆ 92.520539  ┆ … ┆ 0.596871 ┆ OK     ┆ false      ┆ 0.5       │
# │ 6863       ┆ 5        ┆ 0.05       ┆ 95.984635  ┆ … ┆ 0.511194 ┆ OK     ┆ false      ┆ 5.0       │
# │ 6863       ┆ 5        ┆ 0.1        ┆ 114.685488 ┆ … ┆ 0.485698 ┆ OK     ┆ false      ┆ 10.0      │
# │ 6863       ┆ 5        ┆ 0.15       ┆ 151.723622 ┆ … ┆ 0.477965 ┆ OK     ┆ false      ┆ 15.0      │
# │ 6863       ┆ 10       ┆ 0.005      ┆ 94.061049  ┆ … ┆ 0.584245 ┆ OK     ┆ false      ┆ 0.5       │
# │ …          ┆ …        ┆ …          ┆ …          ┆ … ┆ …        ┆ …      ┆ …          ┆ …         │
# │ 47646      ┆ 20       ┆ 0.15       ┆ 102.462926 ┆ … ┆ 0.539757 ┆ OK     ┆ false      ┆ 15.0      │
# │ 47646      ┆ 40       ┆ 0.005      ┆ 104.125211 ┆ … ┆ 0.450412 ┆ OK     ┆ false      ┆ 0.5       │
# │ 47646      ┆ 40       ┆ 0.05       ┆ 100.823041 ┆ … ┆ 0.558378 ┆ OK     ┆ false      ┆ 5.0       │
# │ 47646      ┆ 40       ┆ 0.1        ┆ 97.079853  ┆ … ┆ 0.564958 ┆ OK     ┆ false      ┆ 10.0      │
# │ 47646      ┆ 40       ┆ 0.15       ┆ 97.61376   ┆ … ┆ 0.565392 ┆ OK     ┆ false      ┆ 15.0      │
# └────────────┴──────────┴────────────┴────────────┴───┴──────────┴────────┴────────────┴───────────┘

# %%
df_avg
# Out:
# shape: (16, 9)
# ┌──────────┬────────────┬──────────┬──────────┬───┬──────────┬────────────┬────────────┬───────────┐
# │ n_splits ┆ sample_siz ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time  ┆ std_time   ┆ prop_stat │
# │ ---      ┆ e_pct      ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---        ┆ ---        ┆ us_error  │
# │ i64      ┆ ---        ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64        ┆ f64        ┆ ---       │
# │          ┆ f64        ┆          ┆          ┆   ┆          ┆            ┆            ┆ f64       │
# ╞══════════╪════════════╪══════════╪══════════╪═══╪══════════╪════════════╪════════════╪═══════════╡
# │ 5        ┆ 0.5        ┆ 0.80146  ┆ 0.043131 ┆ … ┆ 0.051647 ┆ 146.924119 ┆ 94.992285  ┆ 0.0       │
# │ 5        ┆ 5.0        ┆ 0.779259 ┆ 0.045917 ┆ … ┆ 0.055927 ┆ 152.660294 ┆ 97.516993  ┆ 0.0       │
# │ 5        ┆ 10.0       ┆ 0.770937 ┆ 0.047713 ┆ … ┆ 0.067554 ┆ 185.641044 ┆ 117.110882 ┆ 0.0       │
# │ 5        ┆ 15.0       ┆ 0.771251 ┆ 0.041971 ┆ … ┆ 0.044293 ┆ 248.637901 ┆ 160.783323 ┆ 0.0       │
# │ 10       ┆ 0.5        ┆ 0.821191 ┆ 0.024928 ┆ … ┆ 0.036688 ┆ 149.951333 ┆ 98.279821  ┆ 0.0       │
# │ …        ┆ …          ┆ …        ┆ …        ┆ … ┆ …        ┆ …          ┆ …          ┆ …         │
# │ 20       ┆ 15.0       ┆ 0.803242 ┆ 0.011406 ┆ … ┆ 0.015436 ┆ 173.636006 ┆ 138.735885 ┆ 0.0       │
# │ 40       ┆ 0.5        ┆ 0.793704 ┆ 0.025572 ┆ … ┆ 0.029116 ┆ 177.42872  ┆ 144.493773 ┆ 0.0       │
# │ 40       ┆ 5.0        ┆ 0.818604 ┆ 0.010036 ┆ … ┆ 0.014221 ┆ 162.85015  ┆ 106.000692 ┆ 0.0       │
# │ 40       ┆ 10.0       ┆ 0.814329 ┆ 0.009052 ┆ … ┆ 0.012449 ┆ 158.368492 ┆ 102.261092 ┆ 0.0       │
# │ 40       ┆ 15.0       ┆ 0.810392 ┆ 0.009254 ┆ … ┆ 0.012689 ┆ 159.344116 ┆ 102.796611 ┆ 0.0       │
# └──────────┴────────────┴──────────┴──────────┴───┴──────────┴────────────┴────────────┴───────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.1
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.1
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.6795190192024405, 0.9251828855594639)
# ylim_ari: (0.4243787375240472, 0.678869543976404)
# ylim_time: (41.834125684709875, 284.94569952245547)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style=None,  
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_fill.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='fill', 
    ylim_acc=ylim_acc,
    ylim_ari=ylim_ari,
    ylim_time=(0,450),   
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_bar.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='bar',   
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_boxplot.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='boxplot', 
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)
