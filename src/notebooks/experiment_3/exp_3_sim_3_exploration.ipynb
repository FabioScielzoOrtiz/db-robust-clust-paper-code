# %%
import os, sys

# %%
# Define el ID del experimento que quieres analizar
DATA_ID = 'simulation_3' 

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
results_dir = os.path.join(project_path, 'results', 'experiment_3', DATA_ID)
filename = f'results_exp_3_{DATA_ID}.pkl'
results_path = os.path.join(results_dir, filename)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_3_results, plot_experiment_3_results
from config.config_experiment_3 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS
)

# %%
df, df_avg = process_experiment_3_results(
    results_path = results_path, 
    prop_errors_threshold = PROP_ERRORS_THRESHOLD
)
# Out:
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 70

# %%
df
# Out:
# shape: (1_120, 9)
# ┌────────────┬──────────┬────────────┬────────────┬───┬──────────┬────────┬────────────┬───────────┐
# │ random_sta ┆ n_splits ┆ frac_sampl ┆ time       ┆ … ┆ ARI      ┆ status ┆ status_err ┆ sample_si │
# │ te         ┆ ---      ┆ e_size     ┆ ---        ┆   ┆ ---      ┆ ---    ┆ or         ┆ ze_pct    │
# │ ---        ┆ i64      ┆ ---        ┆ f64        ┆   ┆ f64      ┆ str    ┆ ---        ┆ ---       │
# │ i64        ┆          ┆ f64        ┆            ┆   ┆          ┆        ┆ bool       ┆ f64       │
# ╞════════════╪══════════╪════════════╪════════════╪═══╪══════════╪════════╪════════════╪═══════════╡
# │ 6863       ┆ 5        ┆ 0.005      ┆ 201.984408 ┆ … ┆ 0.613543 ┆ OK     ┆ false      ┆ 0.5       │
# │ 6863       ┆ 5        ┆ 0.05       ┆ 207.039316 ┆ … ┆ 0.477682 ┆ OK     ┆ false      ┆ 5.0       │
# │ 6863       ┆ 5        ┆ 0.1        ┆ 240.175591 ┆ … ┆ 0.483759 ┆ OK     ┆ false      ┆ 10.0      │
# │ 6863       ┆ 5        ┆ 0.15       ┆ 331.818082 ┆ … ┆ 0.573154 ┆ OK     ┆ false      ┆ 15.0      │
# │ 6863       ┆ 10       ┆ 0.005      ┆ 201.158849 ┆ … ┆ 0.557878 ┆ OK     ┆ false      ┆ 0.5       │
# │ …          ┆ …        ┆ …          ┆ …          ┆ … ┆ …        ┆ …      ┆ …          ┆ …         │
# │ 47646      ┆ 20       ┆ 0.15       ┆ 146.270483 ┆ … ┆ 0.575176 ┆ OK     ┆ false      ┆ 15.0      │
# │ 47646      ┆ 40       ┆ 0.005      ┆ 161.582392 ┆ … ┆ 0.573325 ┆ OK     ┆ false      ┆ 0.5       │
# │ 47646      ┆ 40       ┆ 0.05       ┆ 151.067326 ┆ … ┆ 0.575451 ┆ OK     ┆ false      ┆ 5.0       │
# │ 47646      ┆ 40       ┆ 0.1        ┆ 149.566215 ┆ … ┆ 0.571183 ┆ OK     ┆ false      ┆ 10.0      │
# │ 47646      ┆ 40       ┆ 0.15       ┆ 148.901303 ┆ … ┆ 0.562641 ┆ OK     ┆ false      ┆ 15.0      │
# └────────────┴──────────┴────────────┴────────────┴───┴──────────┴────────┴────────────┴───────────┘

# %%
df_avg
# Out:
# shape: (16, 9)
# ┌──────────┬────────────┬──────────┬──────────┬───┬──────────┬────────────┬───────────┬────────────┐
# │ n_splits ┆ sample_siz ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time  ┆ std_time  ┆ prop_statu │
# │ ---      ┆ e_pct      ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---        ┆ ---       ┆ s_error    │
# │ i64      ┆ ---        ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64        ┆ f64       ┆ ---        │
# │          ┆ f64        ┆          ┆          ┆   ┆          ┆            ┆           ┆ f64        │
# ╞══════════╪════════════╪══════════╪══════════╪═══╪══════════╪════════════╪═══════════╪════════════╡
# │ 5        ┆ 0.5        ┆ 0.796967 ┆ 0.053224 ┆ … ┆ 0.078598 ┆ 149.114996 ┆ 49.396641 ┆ 0.0        │
# │ 5        ┆ 5.0        ┆ 0.788991 ┆ 0.04154  ┆ … ┆ 0.043266 ┆ 152.830869 ┆ 47.334722 ┆ 0.0        │
# │ 5        ┆ 10.0       ┆ 0.779167 ┆ 0.047702 ┆ … ┆ 0.046191 ┆ 187.688437 ┆ 52.74861  ┆ 0.0        │
# │ 5        ┆ 15.0       ┆ 0.779073 ┆ 0.046788 ┆ … ┆ 0.051495 ┆ 258.485359 ┆ 65.923538 ┆ 0.0        │
# │ 10       ┆ 0.5        ┆ 0.824339 ┆ 0.022197 ┆ … ┆ 0.032865 ┆ 146.806953 ┆ 46.572381 ┆ 0.0        │
# │ …        ┆ …          ┆ …        ┆ …        ┆ … ┆ …        ┆ …          ┆ …         ┆ …          │
# │ 20       ┆ 15.0       ┆ 0.803413 ┆ 0.015217 ┆ … ┆ 0.019435 ┆ 166.787341 ┆ 52.076582 ┆ 0.0        │
# │ 40       ┆ 0.5        ┆ 0.795999 ┆ 0.016703 ┆ … ┆ 0.02347  ┆ 171.695338 ┆ 53.682435 ┆ 0.0        │
# │ 40       ┆ 5.0        ┆ 0.824043 ┆ 0.008622 ┆ … ┆ 0.013225 ┆ 167.554626 ┆ 51.391616 ┆ 0.0        │
# │ 40       ┆ 10.0       ┆ 0.817579 ┆ 0.010596 ┆ … ┆ 0.01424  ┆ 163.321011 ┆ 50.236867 ┆ 0.0        │
# │ 40       ┆ 15.0       ┆ 0.81575  ┆ 0.007597 ┆ … ┆ 0.011013 ┆ 164.51002  ┆ 51.172252 ┆ 0.0        │
# └──────────┴────────────┴──────────┴──────────┴───┴──────────┴────────────┴───────────┴────────────┘

# %%
ref_acc = df_avg['mean_acc'].median()
std_acc = df_avg['std_acc'].median()
epsilon_acc =  std_acc + 0.1
ylim_acc = (ref_acc - epsilon_acc, ref_acc + epsilon_acc)

ref_ari = df_avg['mean_ari'].median()
std_ari = df_avg['std_ari'].median()
epsilon_ari = std_ari + 0.1
ylim_ari = (ref_ari - epsilon_ari, ref_ari + epsilon_ari)

ref_time = df_avg['mean_time'].median()
std_time = df_avg['std_time'].median()
epsilon_time = std_time + 10
ylim_time = (ref_time - epsilon_time, ref_time + epsilon_time)

print(f'ylim_acc: {ylim_acc}')
print(f'ylim_ari: {ylim_ari}')
print(f'ylim_time: {ylim_time}')
# Out:
# ylim_acc: (0.6811280136924818, 0.9245484624979945)
# ylim_ari: (0.42420444000140856, 0.6836622596545473)
# ylim_time: (100.72056342766797, 222.69098274474658)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style=None,  
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_fill.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='fill', 
    ylim_acc=ylim_acc,
    ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_bar.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='bar',   
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time, 
    save_path=save_path,
)

# %%
plot_filename = f'plot_results_exp_3_{DATA_ID}_error_boxplot.png'
save_path = os.path.join(results_dir, plot_filename)

plot_experiment_3_results(
    df=df,  
    df_avg=df_avg,                
    data_name=DATA_ID,          
    num_realizations=N_REALIZATIONS,    
    error_style='boxplot', 
    #ylim_acc=ylim_acc,
    #ylim_ari=ylim_ari,
    #ylim_time=ylim_time,   
    save_path=save_path,
)
