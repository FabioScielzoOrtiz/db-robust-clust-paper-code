# %%
import os, sys
import polars as pl

project_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')) 
sys.path.append(project_path)

sys.path.append(project_path)

from src.utils.experiments_exploration_utils import process_experiment_3_results, plot_experiment_3_results
from config.config_experiment_2 import (
    PROP_ERRORS_THRESHOLD,
    N_REALIZATIONS,
    CONFIG_EXPERIMENT
)

DATA_IDS = list(CONFIG_EXPERIMENT.keys())
MODES = ['3a', '3b']

# %%
df_results, df_avg_results = {x: {} for x in DATA_IDS}, {x: {} for x in DATA_IDS}

for data_id in DATA_IDS:

    print('-'*50)
    print(data_id.upper())
    print('-'*50)

    for mode in MODES:

        print('-'*50)
        print(f'experiment_{mode}')
        print('-'*50)

        try:

            results_dir = os.path.join(project_path, 'results', f'experiment_{mode}', data_id)
            filename = f'results_exp_{mode}_{data_id}.pkl'
            results_path = os.path.join(results_dir, filename)

            df, df_avg = process_experiment_3_results(
                results_path=results_path,
                prop_errors_threshold=PROP_ERRORS_THRESHOLD
            )
            
            df_results[data_id][mode] = df.clone()
            df_avg_results[data_id][mode] = df_avg.clone()
            
            with pl.Config(tbl_rows=-1):
                display(df_avg)

        except Exception as e:
            print(e)
# Out:
# --------------------------------------------------
# SIMULATION_BASE
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 100
# shape: (9, 9)
# ┌──────────┬─────────────┬──────────┬──────────┬───┬──────────┬───────────┬──────────┬─────────────┐
# │ n_splits ┆ sample_size ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time ┆ std_time ┆ prop_status │
# │ ---      ┆ _pct        ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---      ┆ _error      │
# │ i64      ┆ ---         ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64       ┆ f64      ┆ ---         │
# │          ┆ f64         ┆          ┆          ┆   ┆          ┆           ┆          ┆ f64         │
# ╞══════════╪═════════════╪══════════╪══════════╪═══╪══════════╪═══════════╪══════════╪═════════════╡
# │ 3        ┆ 20.0        ┆ 0.8558   ┆ 0.106104 ┆ … ┆ 0.196027 ┆ 2.576259  ┆ 1.614143 ┆ 0.0         │
# │ 3        ┆ 30.0        ┆ 0.850285 ┆ 0.113762 ┆ … ┆ 0.200751 ┆ 2.451331  ┆ 1.429436 ┆ 0.0         │
# │ 3        ┆ 40.0        ┆ 0.854819 ┆ 0.110139 ┆ … ┆ 0.196051 ┆ 2.544624  ┆ 1.412471 ┆ 0.0         │
# │ 5        ┆ 20.0        ┆ 0.854105 ┆ 0.107569 ┆ … ┆ 0.194942 ┆ 2.536099  ┆ 1.627335 ┆ 0.0         │
# │ 5        ┆ 30.0        ┆ 0.852857 ┆ 0.106398 ┆ … ┆ 0.196096 ┆ 2.396991  ┆ 1.496897 ┆ 0.0         │
# │ 5        ┆ 40.0        ┆ 0.858054 ┆ 0.100723 ┆ … ┆ 0.190376 ┆ 2.313638  ┆ 1.386006 ┆ 0.0         │
# │ 10       ┆ 20.0        ┆ 0.845187 ┆ 0.108686 ┆ … ┆ 0.201506 ┆ 2.612374  ┆ 1.669192 ┆ 0.0         │
# │ 10       ┆ 30.0        ┆ 0.849071 ┆ 0.106515 ┆ … ┆ 0.198382 ┆ 2.419093  ┆ 1.580105 ┆ 0.0         │
# │ 10       ┆ 40.0        ┆ 0.853086 ┆ 0.103132 ┆ … ┆ 0.196551 ┆ 2.228133  ┆ 1.399581 ┆ 0.0         │
# └──────────┴─────────────┴──────────┴──────────┴───┴──────────┴───────────┴──────────┴─────────────┘
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 100
# shape: (9, 9)
# ┌──────────┬─────────────┬──────────┬──────────┬───┬──────────┬───────────┬──────────┬─────────────┐
# │ n_splits ┆ sample_size ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time ┆ std_time ┆ prop_status │
# │ ---      ┆ _pct        ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---      ┆ _error      │
# │ i64      ┆ ---         ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64       ┆ f64      ┆ ---         │
# │          ┆ f64         ┆          ┆          ┆   ┆          ┆           ┆          ┆ f64         │
# ╞══════════╪═════════════╪══════════╪══════════╪═══╪══════════╪═══════════╪══════════╪═════════════╡
# │ 3        ┆ 20.0        ┆ 0.889775 ┆ 0.015109 ┆ … ┆ 0.030288 ┆ 2.574607  ┆ 1.628329 ┆ 0.0         │
# │ 3        ┆ 30.0        ┆ 0.887796 ┆ 0.011809 ┆ … ┆ 0.026052 ┆ 2.45666   ┆ 1.440239 ┆ 0.0         │
# │ 3        ┆ 40.0        ┆ 0.886704 ┆ 0.012429 ┆ … ┆ 0.027225 ┆ 2.576263  ┆ 1.449153 ┆ 0.0         │
# │ 5        ┆ 20.0        ┆ 0.885882 ┆ 0.018375 ┆ … ┆ 0.038889 ┆ 2.549176  ┆ 1.622184 ┆ 0.0         │
# │ 5        ┆ 30.0        ┆ 0.88951  ┆ 0.011161 ┆ … ┆ 0.024258 ┆ 2.410344  ┆ 1.4582   ┆ 0.0         │
# │ 5        ┆ 40.0        ┆ 0.88776  ┆ 0.010169 ┆ … ┆ 0.022391 ┆ 2.307665  ┆ 1.321641 ┆ 0.0         │
# │ 10       ┆ 20.0        ┆ 0.887534 ┆ 0.008722 ┆ … ┆ 0.019652 ┆ 2.632829  ┆ 1.714466 ┆ 0.0         │
# │ 10       ┆ 30.0        ┆ 0.888102 ┆ 0.00804  ┆ … ┆ 0.01802  ┆ 2.416737  ┆ 1.542045 ┆ 0.0         │
# │ 10       ┆ 40.0        ┆ 0.888591 ┆ 0.008183 ┆ … ┆ 0.018319 ┆ 2.222625  ┆ 1.409054 ┆ 0.0         │
# └──────────┴─────────────┴──────────┴──────────┴───┴──────────┴───────────┴──────────┴─────────────┘
# --------------------------------------------------
# SIMULATION_SIZE_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 100
# shape: (9, 9)
# ┌──────────┬─────────────┬──────────┬──────────┬───┬──────────┬───────────┬───────────┬────────────┐
# │ n_splits ┆ sample_size ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time ┆ std_time  ┆ prop_statu │
# │ ---      ┆ _pct        ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---       ┆ s_error    │
# │ i64      ┆ ---         ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64       ┆ f64       ┆ ---        │
# │          ┆ f64         ┆          ┆          ┆   ┆          ┆           ┆           ┆ f64        │
# ╞══════════╪═════════════╪══════════╪══════════╪═══╪══════════╪═══════════╪═══════════╪════════════╡
# │ 3        ┆ 20.0        ┆ 0.858513 ┆ 0.09765  ┆ … ┆ 0.177733 ┆ 22.905875 ┆ 9.826061  ┆ 0.0        │
# │ 3        ┆ 30.0        ┆ 0.863621 ┆ 0.087662 ┆ … ┆ 0.172683 ┆ 30.161507 ┆ 13.005973 ┆ 0.0        │
# │ 3        ┆ 40.0        ┆ 0.862068 ┆ 0.092016 ┆ … ┆ 0.178426 ┆ 41.001163 ┆ 17.956866 ┆ 0.0        │
# │ 5        ┆ 20.0        ┆ 0.862475 ┆ 0.090804 ┆ … ┆ 0.178908 ┆ 20.992732 ┆ 9.023166  ┆ 0.0        │
# │ 5        ┆ 30.0        ┆ 0.859521 ┆ 0.097138 ┆ … ┆ 0.185627 ┆ 22.720684 ┆ 9.458424  ┆ 0.0        │
# │ 5        ┆ 40.0        ┆ 0.857895 ┆ 0.099865 ┆ … ┆ 0.185994 ┆ 27.795135 ┆ 11.384306 ┆ 0.0        │
# │ 10       ┆ 20.0        ┆ 0.855624 ┆ 0.09796  ┆ … ┆ 0.184558 ┆ 20.674428 ┆ 8.811489  ┆ 0.0        │
# │ 10       ┆ 30.0        ┆ 0.856852 ┆ 0.092957 ┆ … ┆ 0.178944 ┆ 19.645173 ┆ 8.287106  ┆ 0.0        │
# │ 10       ┆ 40.0        ┆ 0.858365 ┆ 0.096065 ┆ … ┆ 0.183377 ┆ 19.061867 ┆ 7.777595  ┆ 0.0        │
# └──────────┴─────────────┴──────────┴──────────┴───┴──────────┴───────────┴───────────┴────────────┘
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ✅ Archivo cargado correctamente. Tipo de objeto: <class 'dict'>
# 📊 Número de realizaciones (seeds) capturadas: 100
# shape: (9, 9)
# ┌──────────┬─────────────┬──────────┬──────────┬───┬──────────┬───────────┬───────────┬────────────┐
# │ n_splits ┆ sample_size ┆ mean_acc ┆ std_acc  ┆ … ┆ std_ari  ┆ mean_time ┆ std_time  ┆ prop_statu │
# │ ---      ┆ _pct        ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---       ┆ s_error    │
# │ i64      ┆ ---         ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64       ┆ f64       ┆ ---        │
# │          ┆ f64         ┆          ┆          ┆   ┆          ┆           ┆           ┆ f64        │
# ╞══════════╪═════════════╪══════════╪══════════╪═══╪══════════╪═══════════╪═══════════╪════════════╡
# │ 3        ┆ 20.0        ┆ 0.871376 ┆ 0.010413 ┆ … ┆ 0.021134 ┆ 15.39163  ┆ 10.341909 ┆ 0.0        │
# │ 3        ┆ 30.0        ┆ 0.868361 ┆ 0.009375 ┆ … ┆ 0.018834 ┆ 19.644152 ┆ 13.24501  ┆ 0.0        │
# │ 3        ┆ 40.0        ┆ 0.865293 ┆ 0.008428 ┆ … ┆ 0.016831 ┆ 25.987834 ┆ 17.935672 ┆ 0.0        │
# │ 5        ┆ 20.0        ┆ 0.878632 ┆ 0.008929 ┆ … ┆ 0.018659 ┆ 13.640448 ┆ 9.327189  ┆ 0.0        │
# │ 5        ┆ 30.0        ┆ 0.873169 ┆ 0.009683 ┆ … ┆ 0.019586 ┆ 14.865974 ┆ 9.844088  ┆ 0.0        │
# │ 5        ┆ 40.0        ┆ 0.870567 ┆ 0.009043 ┆ … ┆ 0.018044 ┆ 18.074018 ┆ 11.669638 ┆ 0.0        │
# │ 10       ┆ 20.0        ┆ 0.885759 ┆ 0.008354 ┆ … ┆ 0.017806 ┆ 13.363942 ┆ 9.398487  ┆ 0.0        │
# │ 10       ┆ 30.0        ┆ 0.881419 ┆ 0.007871 ┆ … ┆ 0.01664  ┆ 12.829478 ┆ 8.736474  ┆ 0.0        │
# │ 10       ┆ 40.0        ┆ 0.879022 ┆ 0.006682 ┆ … ┆ 0.014012 ┆ 12.721472 ┆ 8.37628   ┆ 0.0        │
# └──────────┴─────────────┴──────────┴──────────┴───┴──────────┴───────────┴───────────┴────────────┘
# --------------------------------------------------
# SIMULATION_SIZE_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_DIM_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_DIM_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_NUM_CLUSTERS_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_NUM_CLUSTERS_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_SEPARATION_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_SEPARATION_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_SEPARATION_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_SEPARATION_4
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_CORR_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_CORR_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_OUTLIERS_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_OUTLIERS_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_OUTLIERS_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_OUTLIERS_4
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_IMBALANCE_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_IMBALANCE_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_SPHERICITY_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_SPHERICITY_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_SPHERICITY_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_GEOMETRY_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# SIMULATION_GEOMETRY_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# DUBAI_HOUSES
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# KC_HOUSES
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# HEART_DISEASE
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# ❌ Error: El archivo no existe. Revisa el DATA_ID o la ruta.
# cannot access local variable 'results' where it is not associated with a value

# %%
for data_id in DATA_IDS:

    print('-'*50)
    print(data_id.upper())
    print('-'*50)

    for mode in MODES:

        print('-'*50)
        print(f'experiment_{mode}')
        print('-'*50)

        try:

            error_style = 'fill'
            results_dir = os.path.join(project_path, 'results', f'experiment_{mode}', data_id)
            plot_filename = f'plot_results_exp_{mode}_{data_id}.png'
            save_path = os.path.join(results_dir, plot_filename)

            formatted_data_name = data_id.replace('_', ' ').capitalize()

            title = {
                '3a': f'FoldFastKmedoids Stability against Data Distribution and Sampling Parameters\n{formatted_data_name} - Realizations: {N_REALIZATIONS}',
                '3b': f'FoldFastKmedoids Stability against Sampling Procedure\n{formatted_data_name} - Realizations: {N_REALIZATIONS}'
            } 

            plot_experiment_3_results(
                df=df_results[data_id][mode], 
                df_avg=df_avg_results[data_id][mode],
                error_style=error_style,
                title=title[mode]
                #ylim_acc=ylim_acc,
                #ylim_ari=ylim_ari,
                #ylim_time=ylim_time,
                #save_path=save_path
            )    

        except Exception as e:
            print(e)
# Out:
# --------------------------------------------------
# SIMULATION_BASE
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# --------------------------------------------------
# SIMULATION_SIZE_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# --------------------------------------------------
# SIMULATION_SIZE_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_DIM_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_DIM_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_NUM_CLUSTERS_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_NUM_CLUSTERS_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SEPARATION_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SEPARATION_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SEPARATION_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SEPARATION_4
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_CORR_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_CORR_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_OUTLIERS_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_OUTLIERS_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_OUTLIERS_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_OUTLIERS_4
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_IMBALANCE_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_IMBALANCE_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SPHERICITY_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SPHERICITY_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SPHERICITY_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_GEOMETRY_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_GEOMETRY_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# DUBAI_HOUSES
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# KC_HOUSES
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# HEART_DISEASE
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'

# %%
for data_id in DATA_IDS:

    print('-'*50)
    print(data_id.upper())
    print('-'*50)

    for mode in MODES:

        print('-'*50)
        print(f'experiment_{mode}')
        print('-'*50)

        try:

            error_style = 'boxplot'
            results_dir = os.path.join(project_path, 'results', f'experiment_{mode}', data_id)
            plot_filename = f'plot_results_exp_{mode}_{data_id}.png'
            save_path = os.path.join(results_dir, plot_filename)

            formatted_data_name = data_id.replace('_', ' ').capitalize()

            title = {
                '3a': f'FoldFastKmedoids Stability against Data Distribution and Sampling Parameters\n{formatted_data_name} - Realizations: {N_REALIZATIONS}',
                '3b': f'FoldFastKmedoids Stability against Sampling Procedure\n{formatted_data_name} - Realizations: {N_REALIZATIONS}'
            } 

            plot_experiment_3_results(
                df=df_results[data_id][mode], 
                df_avg=df_avg_results[data_id][mode],
                error_style=error_style,
                title=title[mode]
                #ylim_acc=ylim_acc,
                #ylim_ari=ylim_ari,
                #ylim_time=ylim_time,
                #save_path=save_path
            )    

        except Exception as e:
            print(e)
# Out:
# --------------------------------------------------
# SIMULATION_BASE
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# --------------------------------------------------
# SIMULATION_SIZE_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# --------------------------------------------------
# SIMULATION_SIZE_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_DIM_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_DIM_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_NUM_CLUSTERS_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_NUM_CLUSTERS_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SEPARATION_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SEPARATION_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SEPARATION_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SEPARATION_4
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_CORR_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_CORR_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_OUTLIERS_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_OUTLIERS_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_OUTLIERS_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_OUTLIERS_4
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_IMBALANCE_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_IMBALANCE_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SPHERICITY_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SPHERICITY_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_SPHERICITY_3
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_GEOMETRY_1
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# SIMULATION_GEOMETRY_2
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# DUBAI_HOUSES
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# KC_HOUSES
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
# --------------------------------------------------
# HEART_DISEASE
# --------------------------------------------------
# --------------------------------------------------
# experiment_3a
# --------------------------------------------------
# '3a'
# --------------------------------------------------
# experiment_3b
# --------------------------------------------------
# '3b'
